# %%
drive = "c:\\"
fodler = "reports\\"
filename = "november_production_report"
extension = ".xlsx"
full_path = drive+fodler+filename+extension
print(full_path)
# Out:
# c:\reports\november_production_report.xlsx

# %%
full_path2 = r'c:\reports\november_production_report.xlsx'
print(full_path2)
# Out:
# c:\reports\november_production_report.xlsx

# %%
birth_year = 2010
age = 30

message = "Person born in " + str(birth_year) + " is " + str(age) + " years old in " + str(birth_year+age)

print(message)
# Out:
# Person born in 2010 is 30 years old in 2040

# %%
birth_year = input('Wha is the birth date?')
age=30
type(birth_year)
type(age)
message = "Person born in " + str(birth_year) + " is " + str(age) + " years old in " + str(birth_year+age)
print(message)
